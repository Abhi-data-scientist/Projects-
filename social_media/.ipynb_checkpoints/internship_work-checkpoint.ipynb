# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Task 1: Data Understanding & Cleaning

# %%
df = pd.read_csv('social_media_user_behavior - social_media_user_behavior.csv')
df.head(3)
# Out:
#       user_id  age age_group             gender         country  \
# 0  USR-000001   22     18-24         Non-Binary     Philippines
# 1  USR-000002   31     25-34  Prefer Not to Say  United Kingdom
# 2  USR-000003   21     18-24             Female             UAE
#
#                occupation        education_level income_bracket  \
# 0        Teacher/Educator  Doctoral/Professional    $100K-$150K
# 1  Marketing Professional   High School or Below      $50K-$75K
# 2      Legal Professional   High School or Below      $25K-$50K
#
#   relationship_status primary_platform  ...  productivity_impact  \
# 0             Married         Facebook  ...            No Change
# 1   In a Relationship           TikTok  ...            No Change
# 2              Single        Instagram  ...            Decreased
#
#    platform_satisfaction  account_created_date  account_age_years  \
# 0           Dissatisfied            2025-05-14                0.9
# 1           Dissatisfied            2019-07-18                6.7
# 2                Neutral            2026-01-10                0.2
#
#   is_verified_account is_content_creator uses_ai_features  \
# 0               False              False            False
# 1               False              False            False
# 2               False              False            False
#
#    daily_notifications  checks_phone_first_morning  uses_screen_time_limits
# 0                   20                        True                    False
# 1                   31                        True                    False
# 2                   47                        True                    False
#
# [3 rows x 45 columns]

# %%
df.shape
# Out:
# (25000, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 45 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   user_id                             25000 non-null  object
#  1   age                                 25000 non-null  int64
#  2   age_group                           25000 non-null  object
#  3   gender                              25000 non-null  object
#  4   country                             25000 non-null  object
#  5   occupation                          25000 non-null  object
#  6   education_level                     25000 non-null  object
#  7   income_bracket                      25000 non-null  object
#  8   relationship_status                 25000 non-null  object
#  9   primary_platform                    25000 non-null  object
#  10  num_platforms_used                  25000 non-null  int64
#  11  daily_screen_time_minutes           25000 non-null  int64
#  12  weekly_sessions                     25000 non-null  int64
#  13  avg_session_duration_minutes        25000 non-null  float64
#  14  preferred_content_type              25000 non-null  object
#  15  primary_device                      25000 non-null  object
#  16  usage_purpose                       25000 non-null  object
#  17  posts_per_week                      25000 non-null  int64
#  18  likes_per_day                       25000 non-null  int64
#  19  comments_per_day                    25000 non-null  int64
#  20  shares_per_week                     25000 non-null  int64
#  21  followers_count                     25000 non-null  int64
#  22  following_count                     25000 non-null  int64
#  23  engagement_rate_pct                 25000 non-null  float64
#  24  video_consumption_daily_minutes     25000 non-null  int64
#  25  has_purchased_via_social            25000 non-null  bool
#  26  follows_influencers                 25000 non-null  bool
#  27  ad_click_frequency                  25000 non-null  object
#  28  monthly_social_spending_usd         25000 non-null  float64
#  29  uses_privacy_settings               25000 non-null  bool
#  30  experienced_cyberbullying           25000 non-null  bool
#  31  reports_fake_news_frequency         25000 non-null  object
#  32  self_reported_mental_health_effect  25000 non-null  object
#  33  sleep_hours_per_night               25000 non-null  float64
#  34  addiction_level_1_to_10             25000 non-null  int64
#  35  productivity_impact                 25000 non-null  object
#  36  platform_satisfaction               25000 non-null  object
#  37  account_created_date                25000 non-null  object
#  38  account_age_years                   25000 non-null  float64
#  39  is_verified_account                 25000 non-null  bool
#  40  is_content_creator                  25000 non-null  bool
#  41  uses_ai_features                    25000 non-null  bool
#  42  daily_notifications                 25000 non-null  int64
#  43  checks_phone_first_morning          25000 non-null  bool
#  44  uses_screen_time_limits             25000 non-null  bool
# dtypes: bool(9), float64(5), int64(13), object(18)
# memory usage: 7.1+ MB

# %%
# Checking null values
df.isnull().sum()
# Out:
# user_id                               0
# age                                   0
# age_group                             0
# gender                                0
# country                               0
# occupation                            0
# education_level                       0
# income_bracket                        0
# relationship_status                   0
# primary_platform                      0
# num_platforms_used                    0
# daily_screen_time_minutes             0
# weekly_sessions                       0
# avg_session_duration_minutes          0
# preferred_content_type                0
# primary_device                        0
# usage_purpose                         0
# posts_per_week                        0
# likes_per_day                         0
# comments_per_day                      0
# shares_per_week                       0
# followers_count                       0
# following_count                       0
# engagement_rate_pct                   0
# video_consumption_daily_minutes       0
# has_purchased_via_social              0
# follows_influencers                   0
# ad_click_frequency                    0
# monthly_social_spending_usd           0
# uses_privacy_settings                 0
# experienced_cyberbullying             0
# reports_fake_news_frequency           0
# self_reported_mental_health_effect    0
# sleep_hours_per_night                 0
# addiction_level_1_to_10               0
# productivity_impact                   0
# platform_satisfaction                 0
# account_created_date                  0
# account_age_years                     0
# is_verified_account                   0
# is_content_creator                    0
# uses_ai_features                      0
# daily_notifications                   0
# checks_phone_first_morning            0
# uses_screen_time_limits               0
# dtype: int64

# %%
# Checking duplicate values 
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Task 3: Basic Analysis

# %%
# Average age
df['age'].mean()
# Out:
# np.float64(34.68384)

# %%
# most common gender 
df['gender'].value_counts().sort_values(ascending=False)
# Out:
# gender
# Female               11930
# Male                 11574
# Non-Binary            1009
# Prefer Not to Say      487
# Name: count, dtype: int64

# %%
# top countries which use most social media 
df['country'].value_counts().head(5)
# Out:
# country
# India            3598
# United States    3175
# Brazil           2139
# Indonesia        1646
# Pakistan         1087
# Name: count, dtype: int64

# %%
# most used platform 
df['primary_platform'].value_counts().reset_index(name='count').iloc[0,:]
# Out:
# primary_platform    Instagram
# count                    4434
# Name: 0, dtype: object

# %% [markdown]
# # Task 4: User Behavior Analysis

# %%
# Analyze screen time, addiction level and sleep patterns.

# %%
# Analyze screen time
print('This Time is in minutes')
df['daily_screen_time_minutes'].describe()
# Out:
# This Time is in minutes
# count    25000.000000
# mean       141.122480
# std         62.577221
# min          5.000000
# 25%         95.000000
# 50%        137.000000
# 75%        182.000000
# max        467.000000
# Name: daily_screen_time_minutes, dtype: float64

# %%
# addiction level
df['addiction_level_1_to_10'].value_counts()
# Out:
# addiction_level_1_to_10
# 1     6940
# 3     4889
# 2     4826
# 4     3774
# 5     2548
# 6     1257
# 7      554
# 8      178
# 9       31
# 10       3
# Name: count, dtype: int64

# %%
# sleep patterns
df['sleep_hours_per_night'].describe()
# Out:
# count    25000.000000
# mean         7.026960
# std          0.940823
# min          3.000000
# 25%          6.400000
# 50%          7.000000
# 75%          7.700000
# max         11.000000
# Name: sleep_hours_per_night, dtype: float64

# %% [markdown]
# # Task 5: Relationship Analysis

# %%
# Analyze relationships like screen time vs sleep, followers vs engagement.
# Hint: corr()

# %%
# screen time of sleep hours ke bich correlation negative hai 
df[['daily_screen_time_minutes',  'sleep_hours_per_night']].corr()
# Out:
#                            daily_screen_time_minutes  sleep_hours_per_night
# daily_screen_time_minutes                   1.000000              -0.521594
# sleep_hours_per_night                      -0.521594               1.000000

# %%
# here no relation found in followers count and engagement rate 
df[['followers_count', 'engagement_rate_pct']].corr()
# Out:
#                      followers_count  engagement_rate_pct
# followers_count             1.000000             0.006796
# engagement_rate_pct         0.006796             1.000000

# %% [markdown]
# # Task 6: User Segmentation

# %%
# Create user groups based on usage behavior.
# Hint: df.loc[]

# %%
df.loc[df['daily_screen_time_minutes'] < 95, 'user_type'] = 'Low User'
df.loc[(df['daily_screen_time_minutes'] < 182) & (df['daily_screen_time_minutes'] >= 95), 'user_type'] = 'Medium User'
df.loc[(df['daily_screen_time_minutes'] >= 182), 'user_type'] = 'Heavy User'

# %%
df['user_type'].value_counts()
# Out:
# user_type
# Medium User    12512
# Heavy User      6310
# Low User        6178
# Name: count, dtype: int64

# %% [markdown]
# # Task 7: Business Insights

# %%
# Answer key business questions using data.
# Hint: groupby(), mean()

# %%
# age_group vs daily_screen_time_minutes -> which age group is giving more time to screen 
df.groupby('age_group')['daily_screen_time_minutes'].mean()
# Out:
# age_group
# 13-17    197.089114
# 18-24    176.159116
# 25-34    148.991115
# 35-44    130.016007
# 45-54    104.093655
# 55-64     79.064319
# 65+       54.084817
# Name: daily_screen_time_minutes, dtype: float64

# %%
# gender vs daily_screen_time_minutes 
df.groupby('gender')['daily_screen_time_minutes'].mean()
# Out:
# gender
# Female               141.580302
# Male                 140.583895
# Non-Binary           142.729435
# Prefer Not to Say    139.377823
# Name: daily_screen_time_minutes, dtype: float64

# %%
# primary_platform vs engagement_rate_pct -->  konsa platform jyda engage kar rha hai 
df.groupby('primary_platform')['engagement_rate_pct'].mean().sort_values(ascending=False)
# Out:
# primary_platform
# TikTok         2.795426
# Reddit         2.468691
# RedNote        2.322103
# Instagram      2.200120
# LinkedIn       1.952903
# YouTube        1.910857
# Threads        1.864831
# Snapchat       1.792281
# Bluesky        1.710502
# Pinterest      1.584760
# Facebook       1.501691
# X (Twitter)    1.417487
# Discord        0.000000
# Telegram       0.000000
# WhatsApp       0.000000
# Name: engagement_rate_pct, dtype: float64

# %%
df['primary_platform'].value_counts().reset_index(name='count').iloc[0:4,:]
# Out:
#   primary_platform  count
# 0        Instagram   4434
# 1         Facebook   3939
# 2          YouTube   3759
# 3           TikTok   3594

# %% [markdown]
# # Task 8: Recommendations

# %%
# Provide business suggestions based on insights.
# Hint: Think like a data analyst

# %%
# Target Medium Users for Premium Subscriptions
# Introduce Loyalty Rewards & Badges 

# High screen time → low sleep hours (negative impact)
# Add “Sleep Reminder” feature 
# optimize Night mode / dark mode 
# introduce Digital wellbeing dashboard 

# Younger users → More screen time + engagement -> target them 

# launch Local language content  
# Regional influencers collaborate 

# Followers ≠ engagement 
# improve Fake followers detection 

# High addiction level users are present 
# “Take a break” notification
# promote Screen time limit feature

# %% [markdown]
# # Task 9: Visualization

# %%
# Create 1 bar chart, 1 histogram, 1 heatmap only.

# %%
sns.countplot(x=df['gender'])
plt.title('Gender-Counts')
plt.show()

# %%
sns.histplot(x=df['daily_screen_time_minutes'], kde=True)
plt.show()

# %%
corr = df[['daily_screen_time_minutes', 'sleep_hours_per_night']].corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Task 2: Data Preprocessing

# %%
# Encoding

# %%
df.columns.to_list()
# Out:
# ['user_id',
#  'age',
#  'age_group',
#  'gender',
#  'country',
#  'occupation',
#  'education_level',
#  'income_bracket',
#  'relationship_status',
#  'primary_platform',
#  'num_platforms_used',
#  'daily_screen_time_minutes',
#  'weekly_sessions',
#  'avg_session_duration_minutes',
#  'preferred_content_type',
#  'primary_device',
#  'usage_purpose',
#  'posts_per_week',
#  'likes_per_day',
#  'comments_per_day',
#  'shares_per_week',
#  'followers_count',
#  'following_count',
#  'engagement_rate_pct',
#  'video_consumption_daily_minutes',
#  'has_purchased_via_social',
#  'follows_influencers',
#  'ad_click_frequency',
#  'monthly_social_spending_usd',
#  'uses_privacy_settings',
#  'experienced_cyberbullying',
#  'reports_fake_news_frequency',
#  'self_reported_mental_health_effect',
#  'sleep_hours_per_night',
#  'addiction_level_1_to_10',
#  'productivity_impact',
#  'platform_satisfaction',
#  'account_created_date',
#  'account_age_years',
#  'is_verified_account',
#  'is_content_creator',
#  'uses_ai_features',
#  'daily_notifications',
#  'checks_phone_first_morning',
#  'uses_screen_time_limits',
#  'user_type']

# %%
num_col = df.select_dtypes(include=['int', 'float']).columns
num_col
# Out:
# Index(['age', 'num_platforms_used', 'daily_screen_time_minutes',
#        'weekly_sessions', 'avg_session_duration_minutes', 'posts_per_week',
#        'likes_per_day', 'comments_per_day', 'shares_per_week',
#        'followers_count', 'following_count', 'engagement_rate_pct',
#        'video_consumption_daily_minutes', 'monthly_social_spending_usd',
#        'sleep_hours_per_night', 'addiction_level_1_to_10', 'account_age_years',
#        'daily_notifications'],
#       dtype='object')

# %%
std_cols = [
    'followers_count', 'following_count', 'likes_per_day',
    'comments_per_day', 'shares_per_week',
    'monthly_social_spending_usd', 'daily_notifications'
]

# %%
minmax_cols = [
    'age', 'num_platforms_used', 'daily_screen_time_minutes',
    'weekly_sessions', 'avg_session_duration_minutes',
    'posts_per_week', 'video_consumption_daily_minutes',
    'sleep_hours_per_night', 'addiction_level_1_to_10',
    'account_age_years'
]

# %%
col_for_dummie = ['gender', 'relationship_status', 'primary_platform',
                  'preferred_content_type', 'primary_device', 'usage_purpose',
                  'occupation']

# %%
col_for_label = ['country']

# %%
col_for_ordinal = ['age_group', 'education_level', 'income_bracket',
                   'ad_click_frequency', 'reports_fake_news_frequency',
                   'productivity_impact', 'platform_satisfaction','self_reported_mental_health_effect']

# %%
col_for_true_false = ['has_purchased_via_social', 'follows_influencers',
                      'uses_privacy_settings', 'experienced_cyberbullying',
                     'is_verified_account', 'is_content_creator', 'uses_ai_features',
                      'checks_phone_first_morning', 'uses_screen_time_limits']

# %%
# get_dummies
df = pd.get_dummies(df,columns=col_for_dummie, drop_first=True, dtype=np.int32)

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %%
# Label Encoding
le = LabelEncoder()

# %%
df['country']=le.fit_transform(df['country'])

# %%
# Ordinal_Encoding
oe = OrdinalEncoder(categories=[
                                    ['13-17', '18-24', '25-34', '35-44', '45-54', '55-64', '65+'],  # -> age_group
                                    ['High School or Below','Some College','Vocational/Trade',"Bachelor's Degree",
                                    "Master's Degree",'Doctoral/Professional'],  # -> education
                                    ['< $10K','$10K-$25K','$25K-$50K','$50K-$75K','$75K-$100K','$100K-$150K','$150K+'], # income_bracket
                                    ['Never','Rarely','Sometimes','Often'],  # ad_click_frequency
                                    ['Never','Rarely','Sometimes','Often'],  # reports_fake_news_frequency
                                    ['Decreased', 'No Change', 'Increased'],  # productivity_impact
                                    ['Very Dissatisfied', 'Dissatisfied', 'Neutral', 'Satisfied', 'Very Satisfied'],  # platform_satisfaction
                                    ['Negative', 'Mostly Negative', 'Neutral', 'Mostly Positive', 'Positive'],  # self_reported_mental_health_effect
                               ]
                   )

# %%
df[col_for_ordinal] = oe.fit_transform(df[col_for_ordinal])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Columns: 104 entries, user_id to occupation_Unemployed
# dtypes: bool(9), float64(13), int32(65), int64(14), object(3)
# memory usage: 12.1+ MB

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['user_id', 'account_created_date', 'user_type'], dtype='object')

# %%
df.drop(columns=['user_id', 'account_created_date'], inplace=True)

# %%
df.shape
# Out:
# (25000, 102)

# %%
df.head(3)
# Out:
#    age  age_group  country  education_level  income_bracket  \
# 0   22        1.0       21              5.0             5.0
# 1   31        2.0       32              0.0             3.0
# 2   21        1.0       31              0.0             2.0
#
#    num_platforms_used  daily_screen_time_minutes  weekly_sessions  \
# 0                   6                         89                6
# 1                   6                        161               12
# 2                   6                        342               22
#
#    avg_session_duration_minutes  posts_per_week  ...  \
# 0                          89.0               0  ...
# 1                          93.9               0  ...
# 2                         108.8               9  ...
#
#    occupation_Journalist/Writer  occupation_Legal Professional  \
# 0                             0                              0
# 1                             0                              0
# 2                             0                              1
#
#    occupation_Marketing Professional  occupation_Researcher/Academic  \
# 0                                  0                               0
# 1                                  1                               0
# 2                                  0                               0
#
#    occupation_Retired  occupation_Sales Professional  \
# 0                   0                              0
# 1                   0                              0
# 2                   0                              0
#
#    occupation_Software Engineer  occupation_Student  \
# 0                             0                   0
# 1                             0                   0
# 2                             0                   0
#
#    occupation_Teacher/Educator  occupation_Unemployed
# 0                            1                      0
# 1                            0                      0
# 2                            0                      0
#
# [3 rows x 102 columns]

# %%
# Data dividation

# %%
x = df.drop(columns=['uses_ai_features'])
y = df['uses_ai_features']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
# Standardization

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
sc = StandardScaler()

# %%
x_train_std = sc.fit_transform(x_train[std_cols])

# %%
import copy
x_train_new = copy.deepcopy(x_train)

# %%
x_train_new[std_cols] = pd.DataFrame(x_train_std, columns = x_train[std_cols].columns, index=x_train.index)

# %%
np.round(x_train_new[std_cols].describe(),2)
# Out:
#        followers_count  following_count  likes_per_day  comments_per_day  \
# count         20000.00         20000.00       20000.00          20000.00
# mean             -0.00             0.00           0.00             -0.00
# std               1.00             1.00           1.00              1.00
# min              -0.20            -0.39          -0.95             -0.86
# 25%              -0.19            -0.34          -0.71             -0.86
# 50%              -0.17            -0.26          -0.29             -0.16
# 75%              -0.09            -0.04           0.37              0.53
# max              60.07            30.74           8.71              8.17
#
#        shares_per_week  monthly_social_spending_usd  daily_notifications
# count         20000.00                     20000.00             20000.00
# mean             -0.00                        -0.00                 0.00
# std               1.00                         1.00                 1.00
# min              -0.88                        -1.00                -0.99
# 25%              -0.63                        -0.72                -0.70
# 50%              -0.38                        -0.30                -0.30
# 75%               0.36                         0.39                 0.38
# max              10.56                         9.19                 8.30

# %%
# Normalization

# %%
mn = MinMaxScaler()

# %%
x_train_mn = mn.fit_transform(x_train[minmax_cols])

# %%
x_train_new[minmax_cols] = pd.DataFrame(x_train_mn, columns = x_train[minmax_cols].columns, index=x_train.index)

# %%
np.round(x_train_new[minmax_cols].describe(),2)
# Out:
#             age  num_platforms_used  daily_screen_time_minutes  \
# count  20000.00            20000.00                   20000.00
# mean       0.30                0.35                       0.29
# std        0.21                0.18                       0.14
# min        0.00                0.00                       0.00
# 25%        0.14                0.18                       0.19
# 50%        0.25                0.36                       0.29
# 75%        0.43                0.45                       0.38
# max        1.00                1.00                       1.00
#
#        weekly_sessions  avg_session_duration_minutes  posts_per_week  \
# count         20000.00                      20000.00        20000.00
# mean              0.27                          0.36            0.09
# std               0.17                          0.12            0.10
# min               0.00                          0.00            0.00
# 25%               0.13                          0.28            0.00
# 50%               0.27                          0.36            0.06
# 75%               0.37                          0.43            0.12
# max               1.00                          1.00            1.00
#
#        video_consumption_daily_minutes  sleep_hours_per_night  \
# count                         20000.00               20000.00
# mean                              0.30                   0.50
# std                               0.15                   0.12
# min                               0.00                   0.00
# 25%                               0.19                   0.43
# 50%                               0.29                   0.50
# 75%                               0.39                   0.59
# max                               1.00                   1.00
#
#        addiction_level_1_to_10  account_age_years
# count                 20000.00           20000.00
# mean                      0.21               0.50
# std                       0.19               0.29
# min                       0.00               0.00
# 25%                       0.00               0.25
# 50%                       0.22               0.51
# 75%                       0.33               0.75
# max                       1.00               1.00
