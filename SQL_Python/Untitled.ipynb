# %%
import pandas as pd 
import numpy as np 
import mysql.connector as sq

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\pc\anaconda3\lib\site-packages (9.6.0)Note: you may need to restart the kernel to use updated packages.

# %%
connection = sq.connect(
    host="localhost",     
    user="root",         
    password="mr.abhi1149",      
    database="python_db" 
)

# %%
cursor = connection.cursor()

# %%
cursor.execute("use python_db")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cursor.execute("use python_db")
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:315, in CMySQLCursor.execute(self, operation, params, map_results)
#     312 except (ProgrammingError, ReferenceError) as err:
#     313     raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 315 self._connection.handle_unread_result()
#     316 self.reset()
#     318 stmt = b""
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:1121, in CMySQLConnection.handle_unread_result(self, prepared)
#    1119     self.consume_results()
#    1120 elif unread_result:
# -> 1121     raise InternalError("Unread result found")
#
# InternalError: Unread result found
